# %% [markdown]
# # Simple py5 Examples
#
# These examples use something called "imported mode".  It's a way of coding py5 as if you imported the library with this:
#
# ```
# from py5 import *
# ```
#
# However, you should never import py5 that way. Variables that need to be updated, like `mouse_x` and `mouse_y`, need the py5 kernel to function properly.
#
# Like py5bot, this uses a special Juptyer Notebook kernel. Note the "py5" in the top right corner.

# %% [markdown]
# ## setup
#
# First, define a `setup()` function to create the drawing surface. This will be called once when the Sketch starts.

# %%
def setup():
    size(600, 400)
    background(128)

# %% [markdown]
# ## draw
#
# Second, define a `draw()` function. This will be called repeatedly to create the Sketch animation.

# %%
def draw():
    rect(random(width), random(height), 10, 10)

# %% [markdown]
# ## Run the Sketch!

# %%
run_sketch()

# %% [markdown]
# ## new draw function
#
# This new `draw()` function will replace the `draw()` function defined earlier.

# %%
def draw():
    rect(mouse_x, mouse_y, 10, 10)

# %% [markdown]
# ## Run the Sketch Again!
#
# The second Sketch will use the new `draw()` function and the `settings()` and `setup()` functions from before.

# %%
run_sketch()

# %% [markdown]
# ## Take a Screenshot
#
# If you like, you capture an image of the running window and embed it in the notebook.

# %%
py5_tools.screenshot()

# %% [markdown]
# ## Make an Animated GIF
#
# You can also create an animated GIF.

# %%
py5_tools.animated_gif('images/test.gif', 10, 1, 1)

# %% [markdown]
# The animated GIF can be embedded in the markdown with the appropriate markdown code.
#
# ``` markdown
# ![random white squares](images/test.gif)
# ```
#
# ![random white squares](images/test.gif)
